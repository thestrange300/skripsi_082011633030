# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras import layers, models, optimizers, regularizers
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
from sklearn.utils import class_weight
import numpy as np
from sklearn.metrics import classification_report

# Define the L2 regularization values to test
l2_values = [0.00001, 0.0001, 0.001, 0.01, 0.1]

# Data generators
img_size = (224, 224)
batch_size = 32
train_dir = 'D:\\Splitted Curated X-Ray Dataset\\train'
val_dir = 'D:\\Splitted Curated X-Ray Dataset\\val'
test_dir = 'D:\\Splitted Curated X-Ray Dataset\\test'

train_datagen = ImageDataGenerator(rotation_range=20, zoom_range=0.2, horizontal_flip=True, fill_mode='constant', cval=0, rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
val_generator = val_datagen.flow_from_directory(val_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
test_generator = test_datagen.flow_from_directory(test_dir, target_size=img_size, batch_size=1, class_mode='categorical', shuffle=False)

# Compute class weights
class_counts = np.unique(train_generator.classes, return_counts=True)
class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(train_generator.classes), y=train_generator.classes)
class_weights_dict = {class_label: weight for class_label, weight in zip(class_counts[0], class_weights)}

# Define the initial learning rate and the learning rate schedule
initial_learning_rate = 0.001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True)

# Set up early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)

# Store the results
results = []

results = []
histories = {}

for l2_value in l2_values:
    # Load the ResNet50V2 model with pretrained weights (excluding the top dense layers)
    base_model = ResNet50V2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    
    # Freeze the convolutional layers
    for layer in base_model.layers:
        layer.trainable = False
    
    # Create a new model on top
    model = models.Sequential()
    model.add(base_model)
    model.add(layers.Flatten())
    model.add(layers.Dense(256, activation='relu', kernel_regularizer=regularizers.L2(l2_value)))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(4, activation='softmax'))
    
    # Define the optimizer with the learning rate schedule
    opt = optimizers.Adam(learning_rate=lr_schedule)
    
    # Compile the model
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model
    history = model.fit(train_generator, steps_per_epoch=train_generator.samples // batch_size, epochs=50, validation_data=val_generator, validation_steps=val_generator.samples // batch_size, class_weight=class_weights_dict)
    
    # Store the history
    histories[l2_value] = history
    
    # Evaluate the model on the validation set
    val_loss, val_accuracy = model.evaluate(val_generator, steps=len(val_generator))
    results.append((l2_value, val_loss, val_accuracy))
    
    print(f'L2 Value: {l2_value}, Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}')
    
    # Generate and print the classification report
    y_pred = model.predict(test_generator)
    y_true = test_generator.classes
    y_pred_labels = tf.argmax(y_pred, axis=1)
    class_labels = list(test_generator.class_indices.keys())
    print(f"\nClassification Report for L2 Value {l2_value}:")
    print(classification_report(y_true, y_pred_labels, target_names=class_labels, digits=4))

# Determine the best L2 value
best_l2_value = min(results, key=lambda x: x[1])[0]
print(f'Best L2 Value: {best_l2_value}')

# Train the final model with the best L2 value
base_model = ResNet50V2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in base_model.layers:
    layer.trainable = False

model = models.Sequential()
model.add(base_model)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu', kernel_regularizer=regularizers.L2(best_l2_value)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(4, activation='softmax'))

opt = optimizers.Adam(learning_rate=lr_schedule)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(train_generator, steps_per_epoch=train_generator.samples // batch_size, epochs=50, validation_data=val_generator, validation_steps=val_generator.samples // batch_size, class_weight=class_weights_dict)

# Evaluate the final model on the test set
test_loss, test_accuracy = model.evaluate(test_generator, steps=len(test_generator))
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')

y_pred = model.predict(test_generator)
y_true = test_generator.classes
y_pred_labels = tf.argmax(y_pred, axis=1)
class_labels = list(test_generator.class_indices.keys())
print("\nClassification Report for Best L2 Value:")
print(classification_report(y_true, y_pred_labels, target_names=class_labels, digits=4))

# Save the final model
model.save('D:/UNAIR/SKRIPSI/Seminar Proposal/FIX/Kodingan/Saved Model/resnet50_adam_100_best_l2.keras')
print("Model saved successfully.")

for l2_value, history in histories.items():
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title(f'Model Accuracy for L2 Value {l2_value}')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    
    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(f'Model Loss for L2 Value {l2_value}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    
    plt.tight_layout()
    plt.show()
# Out:
# Found 7364 images belonging to 4 classes.
# Found 920 images belonging to 4 classes.
# Found 924 images belonging to 4 classes.
# Epoch 1/50
# 230/230 [==============================] - 169s 722ms/step - loss: 2.8362 - accuracy: 0.6446 - val_loss: 0.4967 - val_accuracy: 0.7991
# Epoch 2/50
# 230/230 [==============================] - 163s 707ms/step - loss: 0.6980 - accuracy: 0.7047 - val_loss: 0.4969 - val_accuracy: 0.7757
# Epoch 3/50
# 230/230 [==============================] - 161s 699ms/step - loss: 0
#              Normal     0.9636    0.9725    0.9680       327
# Pneumonia-Bacterial     0.8340    0.7342    0.7809       301
#     Pneumonia-Viral     0.5714    0.6707    0.6171       167
#
#            accuracy                         0.8431       924
#           macro avg     0.8329    0.8424    0.8358       924
#        weighted avg     0.8503    0.8431    0.8449       924
#
# Epoch 1/50
# 230/230 [==============================] - 168s 717ms/step - loss: 2.3277 - accuracy: 0.6296 - val_loss: 0.5707 - val_accuracy: 0.7768
# Epoch 2/50
# 230/230 [==============================] - 161s 701ms/step - loss: 0.7380 - accuracy: 0.6911 - val_loss: 0.4927 - val_accuracy: 0.8092
# Epoch 3/50
# 230/230 [==============================] - 161s 700ms/step - loss: 0.6977 - accuracy: 0.7034 - val_loss: 0.5196 - val_accuracy: 0.7958
# Epoch 4/50
# 230/230 [==============================] - 161s 700ms/step - loss: 0.6753 - accuracy: 0.7130 - val_loss: 0.5248 - val_accuracy: 0.7054
# Epoch 5/50
# 230/230 [==============================] - 161s 700ms/step - loss: 0.6831 - accuracy: 0.6945 - val_loss: 0.5736 - val_accuracy: 0.7846
# Epoch 6/50
# 230/230 [==============================] - 180s 782ms/step - loss: 0.6452 - accuracy: 0.7256 - val_loss: 0.5090 - val_accuracy: 0.8248
# Epoch 7/50
# 230/230 [==============================] - 165s 719ms/step - loss: 0.6677 - accuracy: 0.7331 - val_loss: 0.5261 - val_accuracy: 0.7545
# Epoch 8/50
# 230/230 [==============================] - 163s 711ms/step - loss: 0.6568 - accuracy: 0.7345 - val_loss: 0.5072 - val_accuracy: 0.8181
# Epoch 9/50
# 230/230 [==============================] - 164s 712ms/step - loss: 0.6297 - accuracy: 0.7439 - val_loss: 0.7015 - val_accuracy: 0.7712
# Epoch 10/50
# 230/230 [==============================] - 164s 711ms/step - loss: 0.6363 - accuracy: 0.7560 - val_loss: 0.4895 - val_accuracy: 0.8326
# Epoch 11/50
# 230/230 [==============================] - 163s 710ms/step - loss: 0.6371 - accuracy: 0.7638 - val_loss: 0.4942 - val_accuracy: 0.8237
# Epoch 12/50
# 230/230 [==============================] - 164s 713ms/step - loss: 0.6126 - accuracy: 0.7669 - val_loss: 0.5565 - val_accuracy: 0.7991
# Epoch 13/50
# 230/230 [==============================] - 164s 711ms/step - loss: 0.6168 - accuracy: 0.7582 - val_loss: 0.5021 - val_accuracy: 0.8371
# Epoch 14/50
# 230/230 [==============================] - 161s 699ms/step - loss: 0.6205 - accuracy: 0.7679 - val_loss: 0.5066 - val_accuracy: 0.8214
# Epoch 15/50
# 230/230 [==============================] - 160s 696ms/step - loss: 0.6474 - accuracy: 0.7579 - val_loss: 0.5135 - val_accuracy: 0.8393
# Epoch 16/50
# 230/230 [==============================] - 160s 694ms/step - loss: 0.6311 - accuracy: 0.7673 - val_loss: 0.6724 - val_accuracy: 0.7567
# Epoch 17/50
# 230/230 [==============================] - 161s 700ms/step - loss: 0.6309 - accuracy: 0.7657 - val_loss: 0.5008 - val_accuracy: 0.8460
# Epoch 18/50
# 230/230 [==============================] - 165s 716ms/step - loss: 0.6282 - accuracy: 0.7662 - val_loss: 0.4843 - val_accuracy: 0.8393
# Epoch 19/50
# 230/230 [==============================] - 161s 700ms/step - loss: 0.6172 - accuracy: 0.7690 - val_loss: 0.4749 - val_accuracy: 0.8426
# Epoch 20/50
# 230/230 [==============================] - 161s 700ms/step - loss: 0.6326 - accuracy: 0.7625 - val_loss: 0.4723 - val_accuracy: 0.8393
# Epoch 21/50
# 230/230 [==============================] - 160s 696ms/step - loss: 0.6062 - accuracy: 0.7886 - val_loss: 0.4992 - val_accuracy: 0.8493
# Epoch 22/50
# 230/230 [==============================] - 160s 695ms/step - loss: 0.6113 - accuracy: 0.7797 - val_loss: 0.6113 - val_accuracy: 0.8103
# Epoch 23/50
# 230/230 [==============================] - 160s 693ms/step - loss: 0.6153 - accuracy: 0.7713 - val_loss: 0.5796 - val_accuracy: 0.8281
# Epoch 24/50
# 230/230 [==============================] - 160s 696ms/step - loss: 0
50
# 230/230 [==============================] - 160s 694ms/step - loss: 0.6108 - accuracy: 0.7399 - val_loss: 0.5160 - val_accuracy: 0.8225
# Epoch 49/50
# 230/230 [==============================] - 162s 705ms/step - loss: 0.6402 - accuracy: 0.7144 - val_loss: 0.5143 - val_accuracy: 0.8103
# Epoch 50/50
# 230/230 [==============================] - 167s 722ms/step - loss: 0.6299 - accuracy: 0.7366 - val_loss: 0.4905 - val_accuracy: 0.8393
# 29/29 [==============================] - 14s 500ms/step - loss: 0.4970 - accuracy: 0.8337
# L2 Value: 0.0001, Validation Loss: 0.4970, Validation Accuracy: 0.8337
# 924/924 [==============================] - 17s 17ms/step
#
# Classification Report for L2 Value 0.0001:
#                      precision    recall  f1-score   support
#
#            COVID-19     1.0000    0.9690    0.9843       129
#              Normal     0.9124    0.9878    0.9486       327
# Pneumonia-Bacterial     0.7627    0.8007    0.7812       301
#     Pneumonia-Viral     0.6047    0.4671    0.5270       167
#
#            accuracy                         0.8301       924
#           macro avg     0.8199    0.8061    0.8103       924
#        weighted avg     0.8202    0.8301    0.8229       924
#
# Epoch 1/50
# 230/230 [==============================] - 167s 717ms/step - loss: 2.6763 - accuracy: 0.6513 - val_loss: 1.1149 - val_accuracy: 0.6507
# Epoch 2/50
# 230/230 [==============================] - 164s 713ms/step - loss: 0.9929 - accuracy: 0.6687 - val_loss: 0.7179 - val_accuracy: 0.7857
# Epoch 3/50
# 230/230 [==============================] - 164s 711ms/step - loss: 0.9356 - accuracy: 0.6858 - val_loss: 0.8018 - val_accuracy: 0.8002
# Epoch 4/50
# 230/230 [==============================] - 165s 718ms/step - loss: 0.8964 - accuracy: 0.6978 - val_loss: 0.8438 - val_accuracy: 0.6618
# Epoch 5/50
# 230/230 [==============================] - 160s 696ms/step - loss: 0.8205 - accuracy: 0.7212 - val_loss: 0.6448 - val_accuracy: 0.8158
# Epoch 6/50
# 230/230 [==============================] - 160s 695ms/step - loss: 0.8202 - accuracy: 0.7137 - val_loss: 0.6549 - val_accuracy: 0.8069
# Epoch 7/50
# 230/230 [==============================] - 163s 709ms/step - loss: 0.8117 - accuracy: 0.7160 - val_loss: 0.6347 - val_accuracy: 0.8337
# Epoch 8/50
# 230/230 [==============================] - 161s 699ms/step - loss: 0.7824 - accuracy: 0.7313 - val_loss: 0.6976 - val_accuracy: 0.7991
# Epoch 9/50
# 230/230 [==============================] - 163s 710ms/step - loss: 0.7654 - accuracy: 0.7248 - val_loss: 0.6896 - val_accuracy: 0.8125
# Epoch 10/50
# 230/230 [==============================] - 163s 709ms/step - loss: 0.7994 - accuracy: 0.7126 - val_loss: 0.6456 - val_accuracy: 0.6741
# Epoch 11/50
# 230/230 [==============================] - 163s 711ms/step - loss: 0.7808 - accuracy: 0.7208 - val_loss: 0.6251 - val_accuracy: 0.8092
# Epoch 12/50
# 230/230 [==============================] - 163s 709ms/step - loss: 0.7934 - accuracy: 0.7158 - val_loss: 0.7000 - val_accuracy: 0.8080
# Epoch 13/50
# 230/230 [==============================] - 160s 696ms/step - loss: 0.7697 - accuracy: 0.7058 - val_loss: 0.6224 - val_accuracy: 0.8348
# Epoch 14/50
# 230/230 [==============================] - 161s 699ms/step - loss: 0.7768 - accuracy: 0.7068 - val_loss: 0.6672 - val_accuracy: 0.7879
# Epoch 15/50
# 230/230 [==============================] - 161s 698ms/step - loss: 0.7622 - accuracy: 0.7295 - val_loss: 0.6422 - val_accuracy: 0.8192
# Epoch 16/50
# 230/230 [==============================] - 162s 702ms/step - loss: 0.7669 - accuracy: 0.7264 - val_loss: 0.6453 - val_accuracy: 0.7645
# Epoch 17/50
# 230/230 [==============================] - 160s 696ms/step - loss: 0.7870 - accuracy: 0.7143 - val_loss: 0.7296 - val_accuracy: 0.8058
# Epoch 18/50
# 230/230 [==============================] - 162s 702ms/step - loss: 0.7953 - accuracy: 0.7306 - val_loss: 0.6460 - val_accuracy: 0.8281
# Epoch 19/50
# 230/230 [==============================] - 161s 700ms/step - loss: 0
50
# 230/230 [==============================] - 160s 695ms/step - loss: 0.7699 - accuracy: 0.7507 - val_loss: 0.6106 - val_accuracy: 0.8304
# Epoch 44/50
# 230/230 [==============================] - 160s 697ms/step - loss: 0.8044 - accuracy: 0.7548 - val_loss: 0.6454 - val_accuracy: 0.8203
# Epoch 45/50
# 230/230 [==============================] - 160s 695ms/step - loss: 0.8038 - accuracy: 0.7591 - val_loss: 0.7137 - val_accuracy: 0.8013
# Epoch 46/50
# 230/230 [==============================] - 159s 692ms/step - loss: 0.7955 - accuracy: 0.7238 - val_loss: 0.7122 - val_accuracy: 0.8036
# Epoch 47/50
# 230/230 [==============================] - 162s 702ms/step - loss: 0.7671 - accuracy: 0.7665 - val_loss: 0.6166 - val_accuracy: 0.8248
# Epoch 48/50
# 230/230 [==============================] - 163s 709ms/step - loss: 0.7653 - accuracy: 0.7593 - val_loss: 0.6717 - val_accuracy: 0.8114
# Epoch 49/50
# 230/230 [==============================] - 160s 694ms/step - loss: 0.7662 - accuracy: 0.7575 - val_loss: 0.6635 - val_accuracy: 0.7902
# Epoch 50/50
# 230/230 [==============================] - 162s 706ms/step - loss: 0.7603 - accuracy: 0.7557 - val_loss: 0.6157 - val_accuracy: 0.8225
# 29/29 [==============================] - 15s 499ms/step - loss: 0.6158 - accuracy: 0.8228
# L2 Value: 0.001, Validation Loss: 0.6158, Validation Accuracy: 0.8228
# 924/924 [==============================] - 17s 17ms/step
#
# Classification Report for L2 Value 0.001:
#                      precision    recall  f1-score   support
#
#            COVID-19     0.9214    1.0000    0.9591       129
#              Normal     0.9347    0.9633    0.9488       327
# Pneumonia-Bacterial     0.7516    0.7940    0.7722       301
#     Pneumonia-Viral     0.5659    0.4371    0.4932       167
#
#            accuracy                         0.8182       924
#           macro avg     0.7934    0.7986    0.7933       924
#        weighted avg     0.8065    0.8182    0.8104       924
#
# Epoch 1/50
# 230/230 [==============================] - 165s 703ms/step - loss: 4.0734 - accuracy: 0.6537 - val_loss: 1.7255 - val_accuracy: 0.7946
# Epoch 2/50
# 230/230 [==============================] - 160s 696ms/step - loss: 1.5736 - accuracy: 0.6794 - val_loss: 1.1504 - val_accuracy: 0.8092
# Epoch 3/50
# 230/230 [==============================] - 160s 694ms/step - loss: 1.3302 - accuracy: 0.6511 - val_loss: 0.9955 - val_accuracy: 0.7868
# Epoch 4/50
# 230/230 [==============================] - 160s 697ms/step - loss: 1.2756 - accuracy: 0.6687 - val_loss: 0.9703 - val_accuracy: 0.7645
# Epoch 5/50
# 230/230 [==============================] - 161s 698ms/step - loss: 1.0852 - accuracy: 0.6701 - val_loss: 0.8693 - val_accuracy: 0.7980
# Epoch 6/50
# 230/230 [==============================] - 161s 699ms/step - loss: 1.0202 - accuracy: 0.6723 - val_loss: 0.9461 - val_accuracy: 0.7846
# Epoch 7/50
# 230/230 [==============================] - 161s 699ms/step - loss: 1.0291 - accuracy: 0.6736 - val_loss: 0.8404 - val_accuracy: 0.8025
# Epoch 8/50
# 230/230 [==============================] - 160s 693ms/step - loss: 1.3631 - accuracy: 0.6491 - val_loss: 1.1016 - val_accuracy: 0.8192
# Epoch 9/50
# 230/230 [==============================] - 159s 693ms/step - loss: 1.3777 - accuracy: 0.6937 - val_loss: 1.1630 - val_accuracy: 0.7690
# Epoch 10/50
# 230/230 [==============================] - 159s 693ms/step - loss: 1.2367 - accuracy: 0.6564 - val_loss: 1.0261 - val_accuracy: 0.7656
# Epoch 11/50
# 230/230 [==============================] - 163s 708ms/step - loss: 1.2286 - accuracy: 0.6408 - val_loss: 0.9450 - val_accuracy: 0.7824
# Epoch 12/50
# 230/230 [==============================] - 160s 697ms/step - loss: 1
50
# 230/230 [==============================] - 161s 699ms/step - loss: 1.1170 - accuracy: 0.5885 - val_loss: 0.8345 - val_accuracy: 0.6417
# Epoch 38/50
# 230/230 [==============================] - 162s 704ms/step - loss: 1.0785 - accuracy: 0.6204 - val_loss: 0.8943 - val_accuracy: 0.7489
# Epoch 39/50
# 230/230 [==============================] - 165s 718ms/step - loss: 1.0396 - accuracy: 0.6082 - val_loss: 0.8297 - val_accuracy: 0.7946
# Epoch 40/50
# 230/230 [==============================] - 161s 700ms/step - loss: 0.9746 - accuracy: 0.6387 - val_loss: 0.8863 - val_accuracy: 0.7366
# Epoch 41/50
# 230/230 [==============================] - 163s 706ms/step - loss: 0.9569 - accuracy: 0.6418 - val_loss: 0.7846 - val_accuracy: 0.7980
# Epoch 42/50
# 230/230 [==============================] - 161s 698ms/step - loss: 1.0246 - accuracy: 0.6187 - val_loss: 0.9576 - val_accuracy: 0.7589
# Epoch 43/50
# 230/230 [==============================] - 161s 699ms/step - loss: 1.0079 - accuracy: 0.6423 - val_loss: 0.8816 - val_accuracy: 0.7656
# Epoch 44/50
# 230/230 [==============================] - 162s 703ms/step - loss: 0.9748 - accuracy: 0.6461 - val_loss: 0.7714 - val_accuracy: 0.7723
# Epoch 45/50
# 230/230 [==============================] - 161s 698ms/step - loss: 0.9560 - accuracy: 0.6530 - val_loss: 0.8271 - val_accuracy: 0.7812
# Epoch 46/50
# 230/230 [==============================] - 161s 699ms/step - loss: 1.0065 - accuracy: 0.5610 - val_loss: 0.9322 - val_accuracy: 0.6261
# Epoch 47/50
# 230/230 [==============================] - 162s 704ms/step - loss: 0.9899 - accuracy: 0.5561 - val_loss: 0.8274 - val_accuracy: 0.6875
# Epoch 48/50
# 230/230 [==============================] - 161s 699ms/step - loss: 0.9573 - accuracy: 0.5859 - val_loss: 0.9006 - val_accuracy: 0.7634
# Epoch 49/50
# 230/230 [==============================] - 162s 702ms/step - loss: 0.9705 - accuracy: 0.6886 - val_loss: 0.7685 - val_accuracy: 0.7902
# Epoch 50/50
# 230/230 [==============================] - 161s 702ms/step - loss: 0.9741 - accuracy: 0.6971 - val_loss: 0.7585 - val_accuracy: 0.7779
# 29/29 [==============================] - 14s 493ms/step - loss: 0.7614 - accuracy: 0.7783
# L2 Value: 0.01, Validation Loss: 0.7614, Validation Accuracy: 0.7783
# 924/924 [==============================] - 17s 17ms/step
#
# Classification Report for L2 Value 0.01:
#                      precision    recall  f1-score   support
#
#            COVID-19     0.9615    0.9690    0.9653       129
#              Normal     0.9050    0.9327    0.9187       327
# Pneumonia-Bacterial     0.6466    0.8206    0.7233       301
#     Pneumonia-Viral     0.2933    0.1317    0.1818       167
#
#            accuracy                         0.7565       924
#           macro avg     0.7016    0.7135    0.6973       924
#        weighted avg     0.7182    0.7565    0.7283       924
#
# Epoch 1/50
# 230/230 [==============================] - 164s 704ms/step - loss: 8.8501 - accuracy: 0.6356 - val_loss: 1.7655 - val_accuracy: 0.7701
# Epoch 2/50
# 230/230 [==============================] - 162s 704ms/step - loss: 1.6677 - accuracy: 0.6285 - val_loss: 1.4531 - val_accuracy: 0.7768
# Epoch 3/50
# 230/230 [==============================] - 161s 699ms/step - loss: 1.4133 - accuracy: 0.6206 - val_loss: 1.1120 - val_accuracy: 0.7712
# Epoch 4/50
# 230/230 [==============================] - 162s 704ms/step - loss: 1.5948 - accuracy: 0.6200 - val_loss: 2.1032 - val_accuracy: 0.6429
# Epoch 5/50
# 230/230 [==============================] - 160s 698ms/step - loss: 2.1778 - accuracy: 0.6211 - val_loss: 2.0352 - val_accuracy: 0.7243
# Epoch 6/50
# 230/230 [==============================] - 161s 702ms/step - loss: 3.2762 - accuracy: 0.6177 - val_loss: 3.5717 - val_accuracy: 0.7065
# Epoch 7/50
# 230/230 [==============================] - 160s 697ms/step - loss: 2.3276 - accuracy: 0.6372 - val_loss: 1.6918 - val_accuracy: 0.7522
# Epoch 8/50
# 230/230 [==============================] - 161s 699ms/step - loss: 1.6425 - accuracy: 0.6256 - val_loss: 1.2418 - val_accuracy: 0.6864
# Epoch 9/50
# 230/230 [==============================] - 160s 697ms/step - loss: 1.5527 - accuracy: 0.6502 - val_loss: 1.4617 - val_accuracy: 0.7478
# Epoch 10/50
# 230/230 [==============================] - 160s 696ms/step - loss: 1.8636 - accuracy: 0.6049 - val_loss: 2.3861 - val_accuracy: 0.7310
# Epoch 11/50
# 230/230 [==============================] - 162s 706ms/step - loss: 1.7661 - accuracy: 0.6125 - val_loss: 1.3000 - val_accuracy: 0.7556
# Epoch 12/50
# 230/230 [==============================] - 161s 699ms/step - loss: 1.4629 - accuracy: 0.6350 - val_loss: 1.2185 - val_accuracy: 0.7645
# Epoch 13/50
# 230/230 [==============================] - 161s 699ms/step - loss: 1.5251 - accuracy: 0.6191 - val_loss: 1.4833 - val_accuracy: 0.7600
# Epoch 14/50
# 230/230 [==============================] - 162s 703ms/step - loss: 1.5212 - accuracy: 0.6337 - val_loss: 1.2730 - val_accuracy: 0.7679
# Epoch 15/50
# 230/230 [==============================] - 169s 733ms/step - loss: 1.5691 - accuracy: 0.6084 - val_loss: 1.2860 - val_accuracy: 0.7321
# Epoch 16/50
# 230/230 [==============================] - 164s 715ms/step - loss: 1.3621 - accuracy: 0.6300 - val_loss: 1.0895 - val_accuracy: 0.7667
# Epoch 17/50
# 230/230 [==============================] - 162s 704ms/step - loss: 1.5947 - accuracy: 0.6240 - val_loss: 1.2273 - val_accuracy: 0.7645
# Epoch 18/50
# 230/230 [==============================] - 162s 704ms/step - loss: 1.3026 - accuracy: 0.6320 - val_loss: 1.2108 - val_accuracy: 0.6496
# Epoch 19/50
# 230/230 [==============================] - 164s 714ms/step - loss: 1.5497 - accuracy: 0.6204 - val_loss: 1.2746 - val_accuracy: 0.7500
# Epoch 20/50
# 230/230 [==============================] - 165s 715ms/step - loss: 1.4803 - accuracy: 0.6221 - val_loss: 1.0099 - val_accuracy: 0.7790
# Epoch 21/50
# 230/230 [==============================] - 164s 714ms/step - loss: 1.4726 - accuracy: 0.6324 - val_loss: 1.3741 - val_accuracy: 0.7411
# Epoch 22/50
# 230/230 [==============================] - 164s 712ms/step - loss: 1.2861 - accuracy: 0.6388 - val_loss: 1.0552 - val_accuracy: 0.7612
# Epoch 23/50
# 230/230 [==============================] - 164s 714ms/step - loss: 1.3593 - accuracy: 0.5715 - val_loss: 1.0837 - val_accuracy: 0.7210
# Epoch 24/50
# 230/230 [==============================] - 166s 720ms/step - loss: 1.3608 - accuracy: 0.5953 - val_loss: 1.0455 - val_accuracy: 0.7612
# Epoch 25/50
# 230/230 [==============================] - 165s 716ms/step - loss: 1.2444 - accuracy: 0.6331 - val_loss: 0.9656 - val_accuracy: 0.7623
# Epoch 26/50
# 230/230 [==============================] - 167s 725ms/step - loss: 1.3163 - accuracy: 0.6279 - val_loss: 1.9537 - val_accuracy: 0.7165
# Epoch 27/50
# 230/230 [==============================] - 164s 715ms/step - loss: 1.5442 - accuracy: 0.6318 - val_loss: 1.7523 - val_accuracy: 0.7411
# Epoch 28/50
# 230/230 [==============================] - 166s 723ms/step - loss: 1.5584 - accuracy: 0.6323 - val_loss: 1.5025 - val_accuracy: 0.7645
# Epoch 29/50
# 230/230 [==============================] - 166s 722ms/step - loss: 1.3761 - accuracy: 0.6364 - val_loss: 1.0809 - val_accuracy: 0.7701
# Epoch 30/50
# 230/230 [==============================] - 161s 701ms/step - loss: 1.3585 - accuracy: 0.6376 - val_loss: 1.5964 - val_accuracy: 0.7623
# Epoch 31/50
# 230/230 [==============================] - 162s 704ms/step - loss: 1.2523 - accuracy: 0.6436 - val_loss: 1.0175 - val_accuracy: 0.7790
# Epoch 32/50
# 230/230 [==============================] - 162s 703ms/step - loss: 1.3548 - accuracy: 0.6428 - val_loss: 1.0073 - val_accuracy: 0.7065
# Epoch 33/50
# 230/230 [==============================] - 162s 704ms/step - loss: 1.4125 - accuracy: 0.6343 - val_loss: 1.1350 - val_accuracy: 0.7489
# Epoch 34/50
# 230/230 [==============================] - 162s 705ms/step - loss: 1.2788 - accuracy: 0.6361 - val_loss: 1.0462 - val_accuracy: 0.7712
# Epoch 35/50
# 230/230 [==============================] - 164s 715ms/step - loss: 1.2493 - accuracy: 0.6189 - val_loss: 0.9186 - val_accuracy: 0.7500
# Epoch 36/50
# 230/230 [==============================] - 161s 701ms/step - loss: 1.2545 - accuracy: 0.6440 - val_loss: 1.0166 - val_accuracy: 0.7645
# Epoch 37/50
# 230/230 [==============================] - 162s 703ms/step - loss: 1.5973 - accuracy: 0.5876 - val_loss: 0.9089 - val_accuracy: 0.7723
# Epoch 38/50
# 230/230 [==============================] - 165s 716ms/step - loss: 1.2031 - accuracy: 0.6293 - val_loss: 0.9325 - val_accuracy: 0.7612
# Epoch 39/50
# 230/230 [==============================] - 162s 706ms/step - loss: 1.2217 - accuracy: 0.6204 - val_loss: 1.1459 - val_accuracy: 0.7433
# Epoch 40/50
# 230/230 [==============================] - 162s 706ms/step - loss: 1.2700 - accuracy: 0.5968 - val_loss: 0.9425 - val_accuracy: 0.7411
# Epoch 41/50
# 230/230 [==============================] - 163s 707ms/step - loss: 1.2381 - accuracy: 0.6312 - val_loss: 0.9931 - val_accuracy: 0.7656
# Epoch 42/50
# 230/230 [==============================] - 164s 712ms/step - loss: 1.2544 - accuracy: 0.6248 - val_loss: 0.9543 - val_accuracy: 0.7567
# Epoch 43/50
# 230/230 [==============================] - 168s 731ms/step - loss: 1.3235 - accuracy: 0.5656 - val_loss: 1.1492 - val_accuracy: 0.7143
# Epoch 44/50
# 230/230 [==============================] - 161s 698ms/step - loss: 1.2178 - accuracy: 0.6212 - val_loss: 0.9570 - val_accuracy: 0.7377
# Epoch 45/50
# 230/230 [==============================] - 161s 700ms/step - loss: 1.2369 - accuracy: 0.6266 - val_loss: 1.0335 - val_accuracy: 0.7734
# Epoch 46/50
# 230/230 [==============================] - 163s 708ms/step - loss: 1.2420 - accuracy: 0.6050 - val_loss: 1.0613 - val_accuracy: 0.7701
# Epoch 47/50
# 230/230 [==============================] - 166s 720ms/step - loss: 1.2517 - accuracy: 0.5685 - val_loss: 1.0199 - val_accuracy: 0.7701
# Epoch 48/50
# 230/230 [==============================] - 164s 712ms/step - loss: 1.2336 - accuracy: 0.5738 - val_loss: 0.9308 - val_accuracy: 0.7701
# Epoch 49/50
# 230/230 [==============================] - 166s 723ms/step - loss: 1.2423 - accuracy: 0.5638 - val_loss: 1.0801 - val_accuracy: 0.7545
# Epoch 50/50
# 230/230 [==============================] - 166s 723ms/step - loss: 1.2498 - accuracy: 0.5693 - val_loss: 0.9067 - val_accuracy: 0.7444
# 29/29 [==============================] - 15s 495ms/step - loss: 0.9044 - accuracy: 0.7489
# L2 Value: 0.1, Validation Loss: 0.9044, Validation Accuracy: 0.7489
# 924/924 [==============================] - 17s 17ms/step
#
# Classification Report for L2 Value 0.1:
#                      precision    recall  f1-score   support
#
#            COVID-19     0.9528    0.9380    0.9453       129
#              Normal     0.8329    0.9602    0.8920       327
# Pneumonia-Bacterial     0.6492    0.7807    0.7089       301
#     Pneumonia-Viral     0.3621    0.1257    0.1867       167
#
#            accuracy                         0.7478       924
#           macro avg     0.6992    0.7012    0.6832       924
#        weighted avg     0.7047    0.7478    0.7123       924
#
# Best L2 Value: 1e-05
# Epoch 1/50
# 230/230 [==============================] - 169s 724ms/step - loss: 2.0349 - accuracy: 0.6558 - val_loss: 0.5380 - val_accuracy: 0.6942
# Epoch 2/50
# 230/230 [==============================] - 163s 708ms/step - loss: 0.6669 - accuracy: 0.7024 - val_loss: 0.4657 - val_accuracy: 0.7656
# Epoch 3/50
# 230/230 [==============================] - 162s 702ms/step - loss: 0.6242 - accuracy: 0.7061 - val_loss: 0.4627 - val_accuracy: 0.8047
# Epoch 4/50
# 230/230 [==============================] - 161s 701ms/step - loss: 0.6095 - accuracy: 0.7343 - val_loss: 0.4479 - val_accuracy: 0.8103
# Epoch 5/50
# 230/230 [==============================] - 162s 704ms/step - loss: 0.5960 - accuracy: 0.7518 - val_loss: 0.4760 - val_accuracy: 0.7935
# Epoch 6/50
# 230/230 [==============================] - 161s 702ms/step - loss: 0.5761 - accuracy: 0.7477 - val_loss: 0.4788 - val_accuracy: 0.8025
# Epoch 7/50
# 230/230 [==============================] - 160s 696ms/step - loss: 0.5809 - accuracy: 0.7328 - val_loss: 0.4622 - val_accuracy: 0.8080
# Epoch 8/50
# 230/230 [==============================] - 160s 697ms/step - loss: 0.5583 - accuracy: 0.7444 - val_loss: 0.4665 - val_accuracy: 0.8147
# Epoch 9/50
# 230/230 [==============================] - 161s 702ms/step - loss: 0.5591 - accuracy: 0.7350 - val_loss: 0.4705 - val_accuracy: 0.7746
# Epoch 10/50
# 230/230 [==============================] - 164s 715ms/step - loss: 0.5650 - accuracy: 0.7310 - val_loss: 0.4359 - val_accuracy: 0.7958
# Epoch 11/50
# 230/230 [==============================] - 164s 711ms/step - loss: 0.5500 - accuracy: 0.7505 - val_loss: 0.4424 - val_accuracy: 0.8158
# Epoch 12/50
# 230/230 [==============================] - 161s 700ms/step - loss: 0.5341 - accuracy: 0.7545 - val_loss: 0.4129 - val_accuracy: 0.8181
# Epoch 13/50
# 230/230 [==============================] - 160s 698ms/step - loss: 0.5461 - accuracy: 0.7454 - val_loss: 0.4254 - val_accuracy: 0.8292
# Epoch 14/50
# 230/230 [==============================] - 161s 698ms/step - loss: 0.5175 - accuracy: 0.7552 - val_loss: 0.3983 - val_accuracy: 0.8371
# Epoch 15/50
# 230/230 [==============================] - 160s 696ms/step - loss: 0.5423 - accuracy: 0.7505 - val_loss: 0.4343 - val_accuracy: 0.7991
# Epoch 16/50
# 230/230 [==============================] - 162s 703ms/step - loss: 0.5679 - accuracy: 0.7324 - val_loss: 0.5333 - val_accuracy: 0.8125
# Epoch 17/50
# 230/230 [==============================] - 174s 756ms/step - loss: 0.5422 - accuracy: 0.7508 - val_loss: 0.3886 - val_accuracy: 0.8270
# Epoch 18/50
# 230/230 [==============================] - 174s 759ms/step - loss: 0.5443 - accuracy: 0.7523 - val_loss: 0.4528 - val_accuracy: 0.8248
# Epoch 19/50
# 230/230 [==============================] - 176s 765ms/step - loss: 0.5180 - accuracy: 0.7534 - val_loss: 0.4946 - val_accuracy: 0.8214
# Epoch 20/50
# 230/230 [==============================] - 177s 768ms/step - loss: 0.5263 - accuracy: 0.7572 - val_loss: 0.3881 - val_accuracy: 0.8181
# Epoch 21/50
# 230/230 [==============================] - 185s 803ms/step - loss: 0.5403 - accuracy: 0.7533 - val_loss: 0.4142 - val_accuracy: 0.8170
# Epoch 22/50
# 230/230 [==============================] - 175s 761ms/step - loss: 0.5468 - accuracy: 0.7471 - val_loss: 0.4145 - val_accuracy: 0.8136
# Epoch 23/50
# 230/230 [==============================] - 170s 740ms/step - loss: 0.5603 - accuracy: 0.7406 - val_loss: 0.4393 - val_accuracy: 0.8092
# Epoch 24/50
# 230/230 [==============================] - 179s 780ms/step - loss: 0.5263 - accuracy: 0.7553 - val_loss: 0.3970 - val_accuracy: 0.8449
# Epoch 25/50
# 230/230 [==============================] - 171s 744ms/step - loss: 0.5381 - accuracy: 0.7600 - val_loss: 0.5162 - val_accuracy: 0.7790
# Epoch 26/50
# 230/230 [==============================] - 171s 744ms/step - loss: 0.5275 - accuracy: 0.7591 - val_loss: 0.4545 - val_accuracy: 0.8136
# Epoch 27/50
# 230/230 [==============================] - 176s 765ms/step - loss: 0.5096 - accuracy: 0.7593 - val_loss: 0.4822 - val_accuracy: 0.8181
# Epoch 28/50
# 230/230 [==============================] - 176s 766ms/step - loss: 0.5330 - accuracy: 0.7520 - val_loss: 0.4554 - val_accuracy: 0.8359
# Epoch 29/50
# 230/230 [==============================] - 182s 790ms/step - loss: 0.5209 - accuracy: 0.7666 - val_loss: 0.4434 - val_accuracy: 0.8013
# Epoch 30/50
# 168/230 [====================>.........] - ETA: 44s - loss: 0.5354 - accuracy: 0.7536
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 108
#     105 opt = optimizers.Adam(learning_rate=lr_schedule)
#     106 model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# --> 108 history = model.fit(train_generator, steps_per_epoch=train_generator.samples // batch_size, epochs=50, validation_data=val_generator, validation_steps=val_generator.samples // batch_size, class_weight=class_weights_dict)
#     110 # Evaluate the final model on the test set
#     111 test_loss, test_accuracy = model.evaluate(test_generator, steps=len(test_generator))
#
# File c:\Users\VICTUS\.conda\envs\skripsi\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\VICTUS\.conda\envs\skripsi\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File c:\Users\VICTUS\.conda\envs\skripsi\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\VICTUS\.conda\envs\skripsi\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\VICTUS\.conda\envs\skripsi\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\VICTUS\.conda\envs\skripsi\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\VICTUS\.conda\envs\skripsi\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\VICTUS\.conda\envs\skripsi\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\VICTUS\.conda\envs\skripsi\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:
