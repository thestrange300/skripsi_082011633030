# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50V2,VGG16
from tensorflow.keras import layers, models, optimizers, regularizers
from tensorflow.keras.callbacks import Callback, EarlyStopping, LearningRateScheduler

# %%
img_size = (224, 224)

train_datagen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='constant',
    cval=0
)

train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Set the batch size
batch_size = 32

# Specify the paths to your train, validation, and test data
train_dir = 'D:\\Splitted Resized Curated X-Ray Dataset\\train'
val_dir = 'D:\\Splitted Resized Curated X-Ray Dataset\\val'
test_dir = 'D:\\Splitted Resized Curated X-Ray Dataset\\test'

# Flow training images in batches using train_datagen generator
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

# Flow validation images in batches using val_datagen generator
val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
)

# Flow test images in batches using test_datagen generator
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=1,
    class_mode='categorical',
    shuffle = False
)
# Out:
# Found 7364 images belonging to 4 classes.
# Found 920 images belonging to 4 classes.
# Found 924 images belonging to 4 classes.

# %%
from sklearn.utils import class_weight
import numpy as np

class_counts = np.unique(train_generator.classes, return_counts=True)

class_weights = class_weight.compute_class_weight(
    'balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)

class_weights_dict = {class_label: weight for class_label, weight in zip(class_counts[0], class_weights)}

print(class_weights_dict)
# Out:
# {0: 1.7978515625, 1: 0.7037461773700305, 2: 0.7670833333333333, 3: 1.3904833836858006}

# %%
# Get class indices from the training generator
class_indices = train_generator.class_indices

# Count the number of images in each class
num_images_per_class_train = {class_name: len(os.listdir(os.path.join(train_dir, class_name))) for class_name in class_indices.keys()}

# Print the results
print("Number of images in each class for the training set:")
for class_name, num_images in num_images_per_class_train.items():
    print(f"{class_name}: {num_images} images")
# Out:
# Number of images in each class for the training set:
# COVID-19: 1024 images
# Normal: 2616 images
# Pneumonia-Bacterial: 2400 images
# Pneumonia-Viral: 1324 images

# %%
# Load the VGG16 model with pretrained weights (excluding the top dense layers)
base_model = ResNet50V2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the convolutional layers
for layer in base_model.layers:
    layer.trainable = False

# Create a new model on top
model = models.Sequential()

# Add the Resnet50 base model
model.add(base_model)

# Flatten the output layer to 1 dimension
model.add(layers.Flatten())

# Add a fully connected layer with 256 hidden units, ReLU activation
model.add(layers.Dense(256, activation='relu'))

# Add a dropout layer for regularization
model.add(layers.Dropout(0.5))

model.add(layers.BatchNormalization())

# Add the final output layer with 4 classes for classification
model.add(layers.Dense(4, activation='softmax'))

# Print the model summary
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 7, 7, 2048)        23564800
#
#  flatten_2 (Flatten)         (None, 100352)            0
#
#  dense_4 (Dense)             (None, 256)               25690368
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  batch_normalization_2 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_5 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 49,257,220
# Trainable params: 25,691,908
# Non-trainable params: 23,565,312
# _________________________________________________________________

# %%
# Custom callback to delay EarlyStopping
class DelayedEarlyStopping(Callback):
    def __init__(self, monitor='val_loss', patience=7, start_epoch=50, restore_best_weights=True):
        super(DelayedEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.start_epoch = start_epoch
        self.restore_best_weights = restore_best_weights
        self.wait = 0
        self.stopped_epoch = 0
        self.best_weights = None
        self.best = np.Inf

    def on_epoch_end(self, epoch, logs=None):
        current = logs.get(self.monitor)
        if epoch >= self.start_epoch:
            if np.less(current, self.best):
                self.best = current
                self.wait = 0
                if self.restore_best_weights:
                    self.best_weights = self.model.get_weights()
            else:
                self.wait += 1
                if self.wait >= self.patience:
                    self.stopped_epoch = epoch
                    self.model.stop_training = True
                    if self.restore_best_weights:
                        self.model.set_weights(self.best_weights)

    def on_train_end(self, logs=None):
        if self.stopped_epoch > 0:
            print(f'\nEpoch {self.stopped_epoch + 1}: early stopping')

# %%
# Define the initial learning rate and the learning rate schedule
initial_learning_rate = 0.001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=100000, decay_rate=0.000001, staircase=True
)

# Define the optimizer with the learning rate schedule
opt = optimizers.Adam(learning_rate=lr_schedule)

# Compile the model
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# Set up the delayed early stopping callback
delayed_early_stop = DelayedEarlyStopping(monitor='val_loss', patience=7, start_epoch=50, restore_best_weights=True)

# Train the model with the specified number of epochs
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=100,
    validation_data=val_generator,
    validation_steps=val_generator.samples // batch_size,
    callbacks=[delayed_early_stop],
    class_weight=class_weights_dict
)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(test_generator, steps=len(test_generator))
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# Epoch 1/100
# 230/230 [==============================] - 30s 106ms/step - loss: 0.5460 - accuracy: 0.7683 - val_loss: 0.4498 - val_accuracy: 0.8092
# Epoch 2/100
# 230/230 [==============================] - 26s 111ms/step - loss: 0.3472 - accuracy: 0.8526 - val_loss: 0.3467 - val_accuracy: 0.8504
# Epoch 3/100
# 230/230 [==============================] - 25s 109ms/step - loss: 0.2801 - accuracy: 0.8809 - val_loss: 0.3270 - val_accuracy: 0.8549
# Epoch 4/100
# 230/230 [==============================] - 22s 94ms/step - loss: 0.2635 - accuracy: 0.8898 - val_loss: 0.3152 - val_accuracy: 0.8627
# Epoch 5/100
# 230/230 [==============================] - 16s 68ms/step - loss: 0.2334 - accuracy: 0.9021 - val_loss: 0.3414 - val_accuracy: 0.8482
# Epoch 6/100
# 230/230 [==============================] - 16s 68ms/step - loss: 0.2263 - accuracy: 0.9063 - val_loss: 0.3967 - val_accuracy: 0.8493
# Epoch 7/100
# 230/230 [==============================] - 18s 80ms/step - loss: 0.2081 - accuracy: 0.9153 - val_loss: 0.3519 - val_accuracy: 0.8650
# Epoch 8/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.1963 - accuracy: 0.9203 - val_loss: 0.3280 - val_accuracy: 0.8717
# Epoch 9/100
# 230/230 [==============================] - 25s 109ms/step - loss: 0.1859 - accuracy: 0.9244 - val_loss: 0.3038 - val_accuracy: 0.8728
# Epoch 10/100
# 230/230 [==============================] - 24s 106ms/step - loss: 0.1816 - accuracy: 0.9243 - val_loss: 0.4761 - val_accuracy: 0.8203
# Epoch 11/100
# 230/230 [==============================] - 25s 106ms/step - loss: 0.1536 - accuracy: 0.9386 - val_loss: 0.3704 - val_accuracy: 0.8438
# Epoch 12/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.1585 - accuracy: 0.9307 - val_loss: 0.3658 - val_accuracy: 0.8571
# Epoch 13/100
# 230/230 [==============================] - 24s 106ms/step - loss: 0.1408 - accuracy: 0.9452 - val_loss: 0.3378 - val_accuracy: 0.8739
# Epoch 14/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.1344 - accuracy: 0.9469 - val_loss: 0.3513 - val_accuracy: 0.8583
# Epoch 15/100
# 230/230 [==============================] - 25s 109ms/step - loss: 0.1283 - accuracy: 0.9504 - val_loss: 0.3377 - val_accuracy: 0.8717
# Epoch 16/100
# 230/230 [==============================] - 25s 109ms/step - loss: 0.1178 - accuracy: 0.9555 - val_loss: 0.4165 - val_accuracy: 0.8415
# Epoch 17/100
# 230/230 [==============================] - 25s 109ms/step - loss: 0.1091 - accuracy: 0.9577 - val_loss: 0.3709 - val_accuracy: 0.8616
# Epoch 18/100
# 230/230 [==============================] - 26s 111ms/step - loss: 0.1155 - accuracy: 0.9550 - val_loss: 0.5112 - val_accuracy: 0.8147
# Epoch 19/100
# 230/230 [==============================] - 25s 107ms/step - loss: 0.1176 - accuracy: 0.9557 - val_loss: 0.3811 - val_accuracy: 0.8705
# Epoch 20/100
# 230/230 [==============================] - 25s 106ms/step - loss: 0.1155 - accuracy: 0.9524 - val_loss: 0.3673 - val_accuracy: 0.8728
# Epoch 21/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.1095 - accuracy: 0.9561 - val_loss: 0.4798 - val_accuracy: 0.8493
# Epoch 22/100
# 230/230 [==============================] - 24s 104ms/step - loss: 0.1126 - accuracy: 0.9561 - val_loss: 0.4686 - val_accuracy: 0.8471
# Epoch 23/100
# 230/230 [==============================] - 24s 104ms/step - loss: 0.1116 - accuracy: 0.9561 - val_loss: 0.3587 - val_accuracy: 0.8772
# Epoch 24/100
# 230/230 [==============================] - 24s 104ms/step - loss: 0.0982 - accuracy: 0.9592 - val_loss: 0.4419 - val_accuracy: 0.8783
# Epoch 25/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0897 - accuracy: 0.9666 - val_loss: 0.4002 - val_accuracy: 0.8705
# Epoch 26/100
# 230/230 [==============================] - 24s 104ms/step - loss: 0.0784 - accuracy: 0.9708 - val_loss: 0.4509 - val_accuracy: 0.8795
# Epoch 27/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0712 - accuracy: 0.9711 - val_loss: 0.4340 - val_accuracy: 0.8739
# Epoch 28/100
# 230/230 [==============================] - 24s 104ms/step - loss: 0.0762 - accuracy: 0.9708 - val_loss: 0.4934 - val_accuracy: 0.8583
# Epoch 29/100
# 230/230 [==============================] - 24s 104ms/step - loss: 0.0717 - accuracy: 0.9734 - val_loss: 0.4696 - val_accuracy: 0.8638
# Epoch 30/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0714 - accuracy: 0.9737 - val_loss: 0.3969 - val_accuracy: 0.8761
# Epoch 31/100
# 230/230 [==============================] - 24s 104ms/step - loss: 0.0769 - accuracy: 0.9688 - val_loss: 0.4507 - val_accuracy: 0.8795
# Epoch 32/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0697 - accuracy: 0.9735 - val_loss: 0.4660 - val_accuracy: 0.8806
# Epoch 33/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0624 - accuracy: 0.9767 - val_loss: 0.4249 - val_accuracy: 0.8839
# Epoch 34/100
# 230/230 [==============================] - 24s 104ms/step - loss: 0.0585 - accuracy: 0.9770 - val_loss: 0.4908 - val_accuracy: 0.8761
# Epoch 35/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0542 - accuracy: 0.9787 - val_loss: 0.4353 - val_accuracy: 0.8795
# Epoch 36/100
# 230/230 [==============================] - 24s 104ms/step - loss: 0.0632 - accuracy: 0.9749 - val_loss: 0.4719 - val_accuracy: 0.8750
# Epoch 37/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0547 - accuracy: 0.9798 - val_loss: 0.4705 - val_accuracy: 0.8783
# Epoch 38/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0470 - accuracy: 0.9828 - val_loss: 0.5090 - val_accuracy: 0.8694
# Epoch 39/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0626 - accuracy: 0.9744 - val_loss: 0.4945 - val_accuracy: 0.8728
# Epoch 40/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0551 - accuracy: 0.9780 - val_loss: 0.5252 - val_accuracy: 0.8761
# Epoch 41/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0578 - accuracy: 0.9767 - val_loss: 0.4898 - val_accuracy: 0.8705
# Epoch 42/100
# 230/230 [==============================] - 24s 104ms/step - loss: 0.0527 - accuracy: 0.9797 - val_loss: 0.5380 - val_accuracy: 0.8694
# Epoch 43/100
# 230/230 [==============================] - 24s 104ms/step - loss: 0.0594 - accuracy: 0.9746 - val_loss: 0.5705 - val_accuracy: 0.8627
# Epoch 44/100
# 230/230 [==============================] - 24s 104ms/step - loss: 0.0602 - accuracy: 0.9761 - val_loss: 0.4926 - val_accuracy: 0.8638
# Epoch 45/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0742 - accuracy: 0.9705 - val_loss: 0.4087 - val_accuracy: 0.8683
# Epoch 46/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0896 - accuracy: 0.9615 - val_loss: 0.4970 - val_accuracy: 0.8471
# Epoch 47/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0847 - accuracy: 0.9648 - val_loss: 0.4494 - val_accuracy: 0.8806
# Epoch 48/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0721 - accuracy: 0.9724 - val_loss: 0.5572 - val_accuracy: 0.8672
# Epoch 49/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0629 - accuracy: 0.9715 - val_loss: 0.4857 - val_accuracy: 0.8761
# Epoch 50/100
# 230/230 [==============================] - 24s 104ms/step - loss: 0.0791 - accuracy: 0.9682 - val_loss: 0.4917 - val_accuracy: 0.8873
# Epoch 51/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0657 - accuracy: 0.9735 - val_loss: 0.5206 - val_accuracy: 0.8728
# Epoch 52/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0618 - accuracy: 0.9750 - val_loss: 0.4819 - val_accuracy: 0.8806
# Epoch 53/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0548 - accuracy: 0.9780 - val_loss: 0.5264 - val_accuracy: 0.8884
# Epoch 54/100
# 230/230 [==============================] - 24s 106ms/step - loss: 0.0601 - accuracy: 0.9760 - val_loss: 0.4740 - val_accuracy: 0.8817
# Epoch 55/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0506 - accuracy: 0.9805 - val_loss: 0.5893 - val_accuracy: 0.8783
# Epoch 56/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0500 - accuracy: 0.9804 - val_loss: 0.5165 - val_accuracy: 0.8638
# Epoch 57/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0518 - accuracy: 0.9808 - val_loss: 0.5240 - val_accuracy: 0.8728
# Epoch 58/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0579 - accuracy: 0.9779 - val_loss: 0.4722 - val_accuracy: 0.8839
# Epoch 59/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0602 - accuracy: 0.9776 - val_loss: 0.5461 - val_accuracy: 0.8616
# Epoch 60/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0669 - accuracy: 0.9767 - val_loss: 0.5019 - val_accuracy: 0.8795
# Epoch 61/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0560 - accuracy: 0.9774 - val_loss: 0.5297 - val_accuracy: 0.8828
# Epoch 62/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0642 - accuracy: 0.9730 - val_loss: 0.5842 - val_accuracy: 0.8839
# Epoch 63/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0552 - accuracy: 0.9782 - val_loss: 0.5243 - val_accuracy: 0.8828
# Epoch 64/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0516 - accuracy: 0.9801 - val_loss: 0.5307 - val_accuracy: 0.8761
# Epoch 65/100
# 230/230 [==============================] - 24s 105ms/step - loss: 0.0605 - accuracy: 0.9761 - val_loss: 0.4815 - val_accuracy: 0.8817
#
# Epoch 65: early stopping
# 924/924 [==============================] - 16s 18ms/step - loss: 0.6256 - accuracy: 0.8485
# Test Loss: 0.6256
# Test Accuracy: 0.8485

# %%
model.save('D:/UNAIR/SKRIPSI/Seminar Proposal/FIX/Kodingan/Saved Model/resnet50_adam_100_normal_DES_BN.keras')

print("Model saved successfully.")
# Out:
# Model saved successfully.

# %%
from sklearn.metrics import classification_report

# Get predictions on the test set
y_pred = model.predict(test_generator)
y_true = test_generator.classes

# Convert predictions to class labels
y_pred_labels = tf.argmax(y_pred, axis=1)
class_labels = list(test_generator.class_indices.keys())

# Generate and print the classification report
print("\nClassification Report:")
print(classification_report(y_true, y_pred_labels, target_names=class_labels, digits=4))
# Out:
# 924/924 [==============================] - 14s 15ms/step
#
# Classification Report:
#                      precision    recall  f1-score   support
#
#            COVID-19     0.9618    0.9767    0.9692       129
#              Normal     0.9725    0.9725    0.9725       327
# Pneumonia-Bacterial     0.7792    0.8206    0.7994       301
#     Pneumonia-Viral     0.6242    0.5569    0.5886       167
#
#            accuracy                         0.8485       924
#           macro avg     0.8344    0.8317    0.8324       924
#        weighted avg     0.8451    0.8485    0.8462       924

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# Predict the classes for the test set
y_pred = np.argmax(model.predict(test_generator), axis=1)

# Get the true classes for the test set
y_true = test_generator.classes

# Create the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot the confusion matrix using seaborn
class_names = ['COVID-19', 'Normal', 'Pneumonia-Bacterial', 'Pneumonia-Viral']  # Adjust these based on your actual class names
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 924/924 [==============================] - 14s 15ms/step

# %%
import matplotlib.pyplot as plt

def plot_metrics(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 4))

    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train')
    plt.plot(history.history['val_accuracy'], label='Validation')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Assuming 'weighted_history' is the history object returned by model.fit()
plot_metrics(history)

# %%
# Import necessary libraries for ROC AUC visualization
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from itertools import cycle

# Get the true labels and predicted probabilities
y_true = test_generator.classes
y_pred_prob = model.predict(test_generator)

# Binarize the true labels for ROC AUC calculation
from sklearn.preprocessing import label_binarize
class_labels = list(test_generator.class_indices.keys())
n_classes = len(class_labels)
y_true_bin = label_binarize(y_true, classes=[0, 1, 2, 3])

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_true_bin.ravel(), y_pred_prob.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot ROC curves
plt.figure(figsize=(10, 8))
colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'red'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(class_labels[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# 924/924 [==============================] - 13s 15ms/step
